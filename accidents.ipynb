# %%
# Dependencies and Setup
import pandas as pd
import datetime as dt

# File to Load 
load_accident_data = "data/US_Accidents_Dec20.csv"

# Read from CSV
accidents_df = pd.read_csv(load_accident_data)

accidents_df
# Out:
#                 ID    Source    TMC  Severity           Start_Time  \
# 0              A-1  MapQuest  201.0         3  2016-02-08 05:46:00
# 1              A-2  MapQuest  201.0         2  2016-02-08 06:07:59
# 2              A-3  MapQuest  201.0         2  2016-02-08 06:49:27
# 3              A-4  MapQuest  201.0         3  2016-02-08 07:23:34
# 4              A-5  MapQuest  201.0         2  2016-02-08 07:39:07
# ...            ...       ...    ...       ...                  ...
# 4232536  A-4239402      Bing    NaN         2  2019-08-23 18:03:25
# 4232537  A-4239403      Bing    NaN         2  2019-08-23 19:11:30
# 4232538  A-4239404      Bing    NaN         2  2019-08-23 19:00:21
# 4232539  A-4239405      Bing    NaN         2  2019-08-23 19:00:21
# 4232540  A-4239406      Bing    NaN         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  ...  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN  ...
# ...

# %%
accidents_df["Source"].unique()
# Out:
# array(['MapQuest', 'MapQuest-Bing', 'Bing'], dtype=object)

# %%
accidents_df.dtypes
# Out:
# ID                        object
# Source                    object
# TMC                      float64
# Severity                   int64
# Start_Time                object
# End_Time                  object
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  float64
# End_Lng                  float64
# Distance(mi)             float64
# Description               object
# Number                   float64
# Street                    object
# Side                      object
# City                      object
# County                    object
# State                     object
# Zipcode                   object
# Country                   object
# Timezone                  object
# Airport_Code              object
# Weather_Timestamp         object
# Temperature(F)           float64
# Wind_Chill(F)            float64
# Humidity(%)              float64
# Pressure(in)             float64
# Visibility(mi)           float64
# ...

# %%
#accidents_df = accidents_df["Start_Time"].astype('datetime64', copy=True)
accidents_df = accidents_df.astype({'Start_Time': 'datetime64'}) #.dtypes
accidents_df.dtypes
# Out:
# ID                               object
# Source                           object
# TMC                             float64
# Severity                          int64
# Start_Time               datetime64[ns]
# End_Time                         object
# Start_Lat                       float64
# Start_Lng                       float64
# End_Lat                         float64
# End_Lng                         float64
# Distance(mi)                    float64
# Description                      object
# Number                          float64
# Street                           object
# Side                             object
# City                             object
# County                           object
# State                            object
# Zipcode                          object
# Country                          object
# Timezone                         object
# Airport_Code                     object
# Weather_Timestamp                object
# ...

# %%
most_recent = accidents_df.loc[accidents_df["Start_Time"] >= pd.to_datetime('2019-01-01')]
#cutoff = pd.to_datetime('2019-01-01')
#cutoff
#df.sort_values(by=['col1'])
most_recent = most_recent.sort_values(by=['Start_Time'])
most_recent
# Out:
#                 ID    Source    TMC  Severity          Start_Time  \
# 3911749  A-3918613      Bing    NaN         4 2019-01-01 00:00:00
# 3911747  A-3918611      Bing    NaN         4 2019-01-01 00:00:00
# 3911745  A-3918609      Bing    NaN         4 2019-01-01 00:00:00
# 1615988  A-1616096  MapQuest  201.0         3 2019-01-01 00:00:50
# 1615989  A-1616097  MapQuest  201.0         3 2019-01-01 00:03:14
# ...            ...       ...    ...       ...                 ...
# 513368    A-513386  MapQuest  241.0         2 2020-12-31 22:50:29
# 3041801  A-3043223      Bing    NaN         2 2020-12-31 22:51:32
# 3405596  A-3412011      Bing    NaN         2 2020-12-31 22:51:32
# 512936    A-512953  MapQuest  241.0         3 2020-12-31 22:57:02
# 3246425  A-3250725      Bing    NaN         2 2020-12-31 23:28:56
#
#                     End_Time  Start_Lat   Start_Lng    End_Lat     End_Lng  \
# 3911749  2019-01-01 06:00:00  40.829567  -81.366130  40.829571  -81.366117
# ...

# %%
most_recent.to_csv("data\most_recent.csv")

# %%
portland = most_recent.loc[most_recent["City"] == "Portland"]
portland
# Out:
#                 ID         Source    TMC  Severity          Start_Time  \
# 1615955  A-1616063  MapQuest-Bing  201.0         3 2019-01-01 00:48:25
# 3912023  A-3918887           Bing    NaN         2 2019-01-01 01:52:42
# 1615959  A-1616067       MapQuest  201.0         3 2019-01-01 02:38:51
# 1615334  A-1615442       MapQuest  241.0         3 2019-01-01 03:26:56
# 3912035  A-3918899           Bing    NaN         2 2019-01-01 03:33:49
# ...            ...            ...    ...       ...                 ...
# 2976194  A-2976648           Bing    NaN         2 2020-12-31 19:51:37
# 3385656  A-3391796           Bing    NaN         2 2020-12-31 20:09:26
# 3287412  A-3292282           Bing    NaN         2 2020-12-31 20:09:26
# 2954034  A-2954167           Bing    NaN         2 2020-12-31 20:09:31
# 3305863  A-3311027           Bing    NaN         2 2020-12-31 20:09:31
#
#                               End_Time  Start_Lat   Start_Lng    End_Lat  \
# ...
